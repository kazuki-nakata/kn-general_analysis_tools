# %%
import sys
import os
sys.path.append("..")
from datetime import datetime as dt
import geopandas as gpd
import pandas as pd
from dotenv import load_dotenv
import os
import importlib
from knool.helpers import settings
from knool.geodata_processor import geo_info,geo_transform,geo_io
from osgeo import gdal,ogr,osr
import numpy as np
# def get_scene_name_MODIS(dt):
importlib.reload(geo_transform)

test=gpd.read_file(r"../../test_data/TIT_algorithm/matchup/arctic_201410_201506/20141029_20141126.gpkg")


date_column=["StartTime","EndTime","StartTime1","EndTime1","StartTime2","EndTime2"]
for val in date_column:
    test[val]=pd.to_datetime(test[val])
#test[val]
test["MODIS_file"]=test["StartTime1"].apply(get_scene_name_MODIS)
test["MODIS_file"]
test["Ocean"]=test["geometry1"].apply(geo_info.calc_ocean_area_in_polygon)
test["Ocean"]

# geom=ogr.CreateGeometryFromWkt(test["geometry1"].values[10]).Clone()
# ocean_area=geo_info.calc_ocean_area_in_polygon(geom)
# print(ocean_area)
#date0=dt(2013,4,1,12,32)
#get_scene_name_MODIS(date0)
# wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 "https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/61/MOD021KM/2014/059/" --header "Authorization: Bearer INSERT_DOWNLOAD_TOKEN_HERE" -P .
#
# Out:
# ERROR 1: PROJ: proj_create: Error 1027 (Invalid value for an argument): ortho: Invalid value for lat_0: |lat_0| should be <= 90°
# ERROR 1: PROJ: proj_create: unrecognized format / unknown name
# ERROR 1: PROJ: proj_create: Error 1027 (Invalid value for an argument): ortho: Invalid value for lat_0: |lat_0| should be <= 90°
# ERROR 1: PROJ: proj_create: unrecognized format / unknown name
# ERROR 1: PROJ: proj_create: Error 1027 (Invalid value for an argument): ortho: Invalid value for lat_0: |lat_0| should be <= 90°
# ERROR 1: PROJ: proj_create: unrecognized format / unknown name
# ERROR 1: PROJ: proj_create: Error 1027 (Invalid value for an argument): ortho: Invalid value for lat_0: |lat_0| should be <= 90°
# ERROR 1: PROJ: proj_create: unrecognized format / unknown name
# 0      3.710759e+06
# 1      5.441571e+05
# 2      8.944081e+05
# 3      1.177676e+06
# 4      2.483803e+06
#            ...
# 432    3.443283e+06
# 433    2.309016e+06
# 434    3.875677e+06
# 435    3.766851e+06
# 436    2.201042e+06
# Name: Ocean, Length: 437, dtype: float64

# %%
python laads-data-download.py -s "https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/61/MOD021KM/2014/059/" -d test_data 
wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 "https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/61/MOD021KM/2014/059/MOD021KM.A2014059.0315*.gdf" --header "Authorization: Bearer a25ha2F0YTA5MjQ6Ym1GcllYUmhMbXRoZW5WcmFVQnFZWGhoTG1wdzoxNjU0MTg5ODQwOjgxMmUzOTE0NmQ2NWFkNTk2ODcwMTUxNmEwNTEzZDQ5ODdhNGRjMmY" -P .
# Out:
#   Input In [13]
#     python laads-data-download.py -s "https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/61/MOD021KM/2014/059/" -d test_data
#            ^
# SyntaxError: invalid syntax

# %%
test[test["Ocean"]/2000/2000 < 0.25]
# Out:
#             AOI                 StartTime                   EndTime  \
# 53 2014-11-23 04:05:00+00:00        NaT 2014-11-23 04:10:00+00:00      NaT
# 55 2014-11-24 03:10:00+00:00        NaT 2014-11-24 03:15:00+00:00      NaT
#
#                                             geometry1 geometry2  \
# 1   POLYGON Z ((118.0498700913 44.2790268384088 0,...      None
# 2   POLYGON Z ((152.59557499052 56.8176766869791 0...      None
# 6   POLYGON Z ((168.673243542403 64.231836076811 0...      None
# 13  POLYGON Z ((166.941682009579 66.3585412921121 ...      None
# 14  POLYGON Z ((122.073660499127 51.1306692201622 ...      None
# 17  POLYGON Z ((156.001869334717 60.2218090577454 ...      None
# 20  POLYGON Z ((116.723086236917 48.3164901714744 ...      None
# 22  POLYGON Z ((128.916996950055 50.398839843028 0...      None
# 28  POLYGON Z ((123.415651651794 47.6833429029407 ...      None
# 31  POLYGON Z ((159.849556479091 63.0579428515309 ...      None
# 35  POLYGON Z ((117.810633767636 44.6994014831658 ...      None
# 36  POLYGON Z ((152.195700616921 56.4662287393106 ...      None
# 40  POLYGON Z ((168.215686883723 64.0274615744414 ...      None
# 47  POLYGON Z ((121.993696748209 51.2357260228421 ...      None
# 50  POLYGON Z ((155.958195538296 60.1828857896921 ...      None
# 53  POLYGON Z ((116.735041125294 48.3117017960727 ...      None
# 55  POLYGON Z ((128.954875402362 50.3618781274631 ...      None
#
#                                              geometry  \
# 1   POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 2   POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 6   POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 13  POLYGON Z ((139.90652 57.15191 0.00000, 139.87...
# 14  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 17  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 20  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 22  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 28  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 31  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 35  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 36  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 40  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 47  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 50  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 53  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
# 55  POLYGON Z ((140.14790 57.20258 0.00000, 140.02...
#
#                                            MODIS_file          Ocean
# 1   [MYD021KM.A2014302.0410.061, MYD03.A2014302.04...  544157.110277
# 2   [MYD021KM.A2014302.1740.061, MYD03.A2014302.17...  894408.075959
# 6   [MYD021KM.A2014304.1725.061, MYD03.A2014304.17...  930387.922056
# 13  [MYD021KM.A2014307.1755.061, MYD03.A2014307.17...  655417.183771
# 14  [MYD021KM.A2014308.0335.061, MYD03.A2014308.03...  603287.675830
# 17  [MYD021KM.A2014309.1745.061, MYD03.A2014309.17...  652018.459860
# 20  [MYD021KM.A2014311.0405.061, MYD03.A2014311.04...  418170.636181
# 22  [MYD021KM.A2014312.0310.061, MYD03.A2014312.03...  857589.689442
# 28  [MYD021KM.A2014315.0340.061, MYD03.A2014315.03...  759973.327594
# 31  [MYD021KM.A2014316.1750.061, MYD03.A2014316.17...  472601.274769
# 35  [MYD021KM.A2014318.0410.061, MYD03.A2014318.04...  524534.762815
# 36  [MYD021KM.A2014318.1740.061, MYD03.A2014318.17...  904318.702485
# 40  [MYD021KM.A2014320.1725.061, MYD03.A2014320.17...  937460.478159
# 47  [MYD021KM.A2014324.0335.061, MYD03.A2014324.03...  604012.627333
# 50  [MYD021KM.A2014325.1745.061, MYD03.A2014325.17...  654294.721156
# 53  [MYD021KM.A2014327.0405.061, MYD03.A2014327.04...  420840.930100
# 55  [MYD021KM.A2014328.0310.061, MYD03.A2014328.03...  860972.696015
